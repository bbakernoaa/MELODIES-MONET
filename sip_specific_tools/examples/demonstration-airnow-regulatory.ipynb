# %% [markdown]
# # Using MELODIES-MONET for SIP evaluation - AIRNOW regulatory

# %%
# This part is only needed if the script fails because of modules not found 
import sys
sys.path.append('/glade/campaign/acom/acom-weather/pfister/ANALYSIS/MELODIES/monetio')
sys.path.append('/glade/campaign/acom/acom-weather/pfister/ANALYSIS/MELODIES/monet')
sys.path.append('/glade/campaign/acom/acom-weather/pfister/ANALYSIS/MELODIES/MELODIES-MONET/')
# %load_ext autoreload
# %autoreload 2
from melodies_monet import driver
driver.__file__
import melodies_monet as mm
import monetio as mio
print(mio.__file__)
import monet
print(monet.__file__)
# Out:
# /glade/campaign/acom/acom-weather/pfister/ANALYSIS/MELODIES/monetio/monetio/__init__.py
# /glade/campaign/acom/acom-weather/pfister/ANALYSIS/MELODIES/monet/monet/__init__.py
# /glade/work/pfister/conda-envs/melodies-monet/lib/python3.11/site-packages/esmpy/interface/loadESMF.py:94: VersionWarning: ESMF installation version 8.8.0, ESMPy version 8.8.0b0
#   warnings.warn("ESMF installation version {}, ESMPy version {}".format(

# %%
from melodies_monet import driver

an = driver.analysis()
an.control = 'control_camx_airnow_reg.yaml'
an.read_control()
an.open_obs()
an.open_models()
an.pair_data()
an.plotting()
an.stats()
# Out:
# camx
# /glade/campaign/acom/acom-da/Denver2024-SIP/Denver_O3_2023/camx/outputs/runS20_2016/camxv72_cb6r5.201607*.runS20.avrg.grd03.nc
# /glade/campaign/acom/acom-weather/pfister/ANALYSIS/MELODIES/monetio/monetio/models/_camx_mm.py:78: UserWarning: Filename for meteorological input not provided. Adding only altitude.
#   warnings.warn("Filename for meteorological input not provided. Adding only altitude.")
# /glade/work/pfister/conda-envs/melodies-monet/lib/python3.11/site-packages/pyproj/crs/crs.py:1295: UserWarning: You will likely lose important projection information when converting to a PROJ string from another format. See: https://proj.org/faq.html#what-is-the-best-format-for-describing-coordinate-reference-systems
#   proj = self._crs.to_proj4(version=version)
# 1, in pair data
# After pairing:                time  BARPR   BC   CO            NO           NO2  NO2Y  NOX
# 0       2016-05-06   -1.0 -1.0 -1.0 -1.000000e+00 -1.000000e+00  -1.0 -1.0  \
# 1       2016-05-06   -1.0 -1.0 -1.0  9.634533e-08  3.000000e+00  -1.0 -1.0
# 2       2016-05-06   -1.0 -1.0 -1.0 -1.000000e+00 -1.000000e+00  -1.0 -1.0
# 3       2016-05-06   -1.0 -1.0 -1.0  9.634533e-08  1.536682e-08  -1.0 -1.0
# 4       2016-05-06   -1.0 -1.0 -1.0  3.000000e+00 -1.000000e+00  -1.0 -1.0
# ...            ...    ...  ...  ...           ...           ...   ...  ...
# 4990740 2016-08-20   -1.0 -1.0 -1.0 -1.000000e+00 -1.000000e+00  -1.0 -1.0
# 4990741 2016-08-20   -1.0 -1.0 -1.0 -1.000000e+00 -1.000000e+00  -1.0 -1.0
# 4990742 2016-08-20   -1.0 -1.0 -1.0 -1.000000e+00 -1.000000e+00  -1.0 -1.0
# 4990743 2016-08-20   -1.0 -1.0 -1.0 -1.000000e+00 -1.000000e+00  -1.0 -1.0
# 4990744 2016-08-20   -1.0 -1.0 -1.0 -1.000000e+00 -1.000000e+00  -1.0 -1.0
#
#          NOY   OC  ...                  site  utcoffset   latitude
# 0       -1.0 -1.0  ...             Goose Bay         -4  53.304700  \
# 1       -1.0 -1.0  ...         CHARLOTTETOWN         -4  46.240600
# 2       -1.0 -1.0  ...            WELLINGTON         -4  46.478300
# 3       -1.0 -1.0  ...           SOUTHAMPTON         -4  46.386400
# 4       -1.0 -1.0  ...               HALIFAX         -4  44.647800
# ...      ...  ...  ...                   ...        ...        ...
# 4990740 -1.0 -1.0  ...              Nespelem         -8  48.167490
# 4990741 -1.0 -1.0  ...             Inchelium         -8  48.296960
# 4990742 -1.0 -1.0  ...  Santa Rosa Rancheria         -8  36.233333
# 4990743 -1.0 -1.0  ...                 Miami         -6  36.922222
# 4990744 -1.0 -1.0  ...           Ulaanbaatar          8  47.928385
#
#           longitude  cmsa_name      msa_code     msa_name  state_name
# 0        -60.364400       -1.0     -1.000000                       CC  \
# 1        -63.130600       -1.0     -1.000000                       CC
# 2        -63.986900       -1.0     -1.000000                       CC
# 3        -62.582800       -1.0     -1.000000                       CC
# 4        -63.572200       -1.0     -1.000000                       CC
# ...             ...        ...           ...          ...         ...
# 4990740 -118.973750       -1.0     -1.000000
# 4990741 -118.202420       -1.0     -1.000000
# 4990742 -119.765083       -1.0     -1.000000
# 4990743  -94.838890       -1.0  33059.999999   Miami, OK
# 4990744  106.929470       -1.0     -1.000000
#
#          epa_region  O3
# 0                CA NaN
# 1                CA NaN
# 2                CA NaN
# 3                CA NaN
# 4                CA NaN
# ...             ...  ..
# 4990740         R10 NaN
# 4990741         R10 NaN
# 4990742             NaN
# 4990743          R6 NaN
# 4990744        DSMG NaN
#
# [4990745 rows x 35 columns]
# saving pair
# Warning: ty_scale not specified for OZONE, so default used.
# Reference std: 13.995685381554365
