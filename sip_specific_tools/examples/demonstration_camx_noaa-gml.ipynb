# %%
# Compare CAMx to NOAA GML surface ozone (

# %%
# This part is only needed if the script fails because of modules not found 
import sys
sys.path.append('/glade/campaign/acom/acom-weather/pfister/ANALYSIS/MELODIES/monetio')
sys.path.append('/glade/campaign/acom/acom-weather/pfister/ANALYSIS/MELODIES/monet')
sys.path.append('/glade/campaign/acom/acom-weather/pfister/ANALYSIS/MELODIES/MELODIES-MONET/')
# %load_ext autoreload
# %autoreload 2

import melodies_monet as mm
print(mm.__file__)
import monetio as mio
print(mio.__file__)
import monet
print(monet.__file__)
from melodies_monet import driver
import numpy as np
# Out:
# /glade/campaign/acom/acom-weather/pfister/ANALYSIS/MELODIES/MELODIES-MONET/melodies_monet/__init__.py
# /glade/campaign/acom/acom-weather/pfister/ANALYSIS/MELODIES/monetio/monetio/__init__.py
# /glade/campaign/acom/acom-weather/pfister/ANALYSIS/MELODIES/monet/monet/__init__.py

# %%
an = driver.analysis()
an.control = 'control_noaa_gml_ASCII.yaml'
an.read_control()
an.open_models()
an.open_obs()
# Out:
# camx
# /glade/campaign/acom/acom-da/Denver2024-SIP/Denver_O3_2023/camx/outputs/runS20_2016/camxv72_cb6r5.201606*.runS20.avrg.grd03.nc
# /glade/work/pfister/conda-envs/melodies-monet/lib/python3.11/site-packages/pyproj/crs/crs.py:1295: UserWarning: You will likely lose important projection information when converting to a PROJ string from another format. See: https://proj.org/faq.html#what-is-the-best-format-for-describing-coordinate-reference-systems
#   proj = self._crs.to_proj4(version=version)

# %%
an.pair_data()
# Out:
# 1, in pair data
# After pairing:      siteid  O3_obs                time  latitude  longitude         O3
# 0      nwr   56.41 2016-06-01 00:00:00   40.0531  -105.5864  39.236271
# 1      nwr   51.27 2016-06-01 01:00:00   40.0531  -105.5864  40.101448
# 2      nwr   35.37 2016-06-01 02:00:00   40.0531  -105.5864  39.824806
# 3      nwr   23.44 2016-06-01 03:00:00   40.0531  -105.5864  39.948616
# 4      nwr   23.99 2016-06-01 04:00:00   40.0531  -105.5864  39.389164
# ..     ...     ...                 ...       ...        ...        ...
# 715    nwr   47.03 2016-06-30 19:00:00   40.0531  -105.5864  53.390194
# 716    nwr   40.88 2016-06-30 20:00:00   40.0531  -105.5864  56.696331
# 717    nwr   37.35 2016-06-30 21:00:00   40.0531  -105.5864  56.922352
# 718    nwr   39.64 2016-06-30 22:00:00   40.0531  -105.5864  54.253136
# 719    nwr   38.38 2016-06-30 23:00:00   40.0531  -105.5864  54.332527
#
# [720 rows x 6 columns]

# %%
an.save_analysis()
# Out:
# Writing: ./NWR_noaa_gml_CAMx.nc4

# %%
an.read_analysis()
# Out:
# Reading: ./NWR_noaa_gml_CAMx.nc4

# %%
an.plotting()
# Out:
# Warning: vmin_plot and vmax_plot not specified for O3_obs, so default used.
# Warning: vmin_plot and vmax_plot not specified for O3_obs, so default used.
# Warning: ty_scale not specified for O3_obs, so default used.
# Reference std: 11.682003129808892
# Warning: vdiff_plot not specified for O3_obs, so default used.
# Warning: vmin_plot and vmax_plot not specified for O3_obs, so default used.
# NOTE: Projection not defined for model 'camx'. Please add to surfplots.py. Setting to `ccrs.PlateCarree()`.

# %%
an.stats()
