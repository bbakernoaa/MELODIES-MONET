# %% [markdown]
# # Using MELODIES-MONET for SIP evaluation - BoulderAir surface measurements

# %%
# This part is only needed if the script fails because of modules not found 
import sys
sys.path.append('/glade/campaign/acom/acom-weather/pfister/ANALYSIS/MELODIES/monetio')
sys.path.append('/glade/campaign/acom/acom-weather/pfister/ANALYSIS/MELODIES/monet')
sys.path.append('/glade/campaign/acom/acom-weather/pfister/ANALYSIS/MELODIES/MELODIES-MONET/')
# %load_ext autoreload
# %autoreload 2
from melodies_monet import driver
driver.__file__
import melodies_monet as mm
import monetio as mio
print(mio.__file__)
import monet
print(monet.__file__)
# Out:
# /glade/campaign/acom/acom-weather/pfister/ANALYSIS/MELODIES/monetio/monetio/__init__.py
# /glade/campaign/acom/acom-weather/pfister/ANALYSIS/MELODIES/monet/monet/__init__.py
# /glade/work/pfister/conda-envs/melodies-monet/lib/python3.11/site-packages/esmpy/interface/loadESMF.py:94: VersionWarning: ESMF installation version 8.8.0, ESMPy version 8.8.0b0
#   warnings.warn("ESMF installation version {}, ESMPy version {}".format(

# %%
from melodies_monet import driver

an = driver.analysis()
an.control = 'control_camx_boulderair.yaml'
an.read_control()
an.open_models()
an.open_obs()
an.pair_data()
an.save_analysis()
an.read_analysis()
an.plotting()
an.stats()
# Out:
# camx
# /glade/work/plichtig/camx/processors/wrfcamx_v5.2/camx_input/CAMx73.cb7r1_cf3.20220720.35.camx.avrg.grd03.nc
# /glade/work/pfister/conda-envs/melodies-monet/lib/python3.11/site-packages/pyproj/crs/crs.py:1295: UserWarning: You will likely lose important projection information when converting to a PROJ string from another format. See: https://proj.org/faq.html#what-is-the-best-format-for-describing-coordinate-reference-systems
#   proj = self._crs.to_proj4(version=version)
# 1, in pair data
# After pairing:                        time siteid  longitude  latitude  elevation     no
# 0      2022-06-30 10:00:00    BRZ -105.22020   40.0700     1586.0  0.025  \
# 1      2022-06-30 10:00:00    BSE -105.03640   39.9844     1607.0  0.025
# 2      2022-06-30 10:00:00    LUR -105.04770   40.1762     1514.0  0.025
# 3      2022-06-30 10:00:00    ECC -105.05190   40.0402     1538.0  0.025
# 4      2022-06-30 10:00:00    BLV -105.04590   39.9787     1602.0  0.025
# ...                    ...    ...        ...       ...        ...    ...
# 322555 2022-08-01 09:59:00    LUR -105.04770   40.1762     1514.0  0.025
# 322556 2022-08-01 09:59:00    ECC -105.05190   40.0402     1538.0  0.025
# 322557 2022-08-01 09:59:00    BLV -105.04590   39.9787     1602.0  0.025
# 322558 2022-08-01 09:59:00    LLG -105.14430   40.1615     1526.0  0.025
# 322559 2022-08-01 09:59:00    BNP -105.00655   39.9814     1611.0  0.025
#
#           no2    nox  NO  NO2
# 0       2.948  2.946 NaN  NaN
# 1       2.948  2.946 NaN  NaN
# 2       2.948  2.946 NaN  NaN
# 3       2.948  2.946 NaN  NaN
# 4       2.948  2.946 NaN  NaN
# ...       ...    ...  ..  ...
# 322555  3.014  2.962 NaN  NaN
# 322556  3.014  2.962 NaN  NaN
# 322557  3.014  2.962 NaN  NaN
# 322558  3.014  2.962 NaN  NaN
# 322559  3.014  2.962 NaN  NaN
#
# [322560 rows x 10 columns]
# saving pair
# Writing: ./output/boulderair/boulderair_CAMX.nc4
# Reading: ./output/boulderair/boulderair_CAMX.nc4
# Warning: variables dict for no not provided, so defaults used
# Warning: vmin_plot and vmax_plot not specified for no2, so default used.
# Warning: variables dict for no not provided, so defaults used
# Warning: vmin_plot and vmax_plot not specified for no2, so default used.
# Warning: variables dict for no not provided, so defaults used
# Reference std: 0.41475231149603536
# Warning: ty_scale not specified for no2, so default used.
# Reference std: 2.0889805395372205
# Warning: variables dict for no not provided, so defaults used
# Warning: vdiff_plot not specified for no2, so default used.
# Warning: variables dict for no not provided, so defaults used
# NOTE: Projection not defined for model 'camx'. Please add to surfplots.py. Setting to `ccrs.PlateCarree()`.
# Warning: vmin_plot and vmax_plot not specified for no2, so default used.
# NOTE: Projection not defined for model 'camx'. Please add to surfplots.py. Setting to `ccrs.PlateCarree()`.
