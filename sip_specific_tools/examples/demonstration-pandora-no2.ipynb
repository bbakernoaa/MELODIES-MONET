# %% [markdown]
# # Using MELODIES-MONET for SIP evaluation - PANDORA NO2

# %%
# This part is only needed if the script fails because of modules not found 

import sys
sys.path.append('/glade/campaign/acom/acom-weather/pfister/ANALYSIS/MELODIES/monetio')
sys.path.append('/glade/campaign/acom/acom-weather/pfister/ANALYSIS/MELODIES/monet')
sys.path.append('/glade/campaign/acom/acom-weather/pfister/ANALYSIS/MELODIES/MELODIES-MONET/')

from melodies_monet import driver
driver.__file__
import melodies_monet as mm
import monetio as mio
print(mio.__file__)
import monet
print(monet.__file__)
from melodies_monet import driver
import numpy as np
# Out:
# /glade/campaign/acom/acom-weather/pfister/ANALYSIS/MELODIES/monetio/monetio/__init__.py
# /glade/campaign/acom/acom-weather/pfister/ANALYSIS/MELODIES/monet/monet/__init__.py
# /glade/work/pfister/conda-envs/melodies-monet/lib/python3.11/site-packages/esmpy/interface/loadESMF.py:94: VersionWarning: ESMF installation version 8.8.0, ESMPy version 8.8.0b0
#   warnings.warn("ESMF installation version {}, ESMPy version {}".format(

# %%
an = driver.analysis()
an.control = 'control_camx_pandora_no2.yaml'
an.read_control()
an.open_obs()
# Out:
# Importing pandora data. The data will be presented as hourly means.
# Calculating pandora hourly averages

# %%
an.open_models()
# Out:
# camx
# /glade/campaign/acom/acom-da/Denver2024-SIP/Example_Files/CAMx73.cb7r1_cf3.20220720.35.camx.avrg.grd03.nc
# /glade/work/pfister/conda-envs/melodies-monet/lib/python3.11/site-packages/pyproj/crs/crs.py:1295: UserWarning: You will likely lose important projection information when converting to a PROJ string from another format. See: https://proj.org/faq.html#what-is-the-best-format-for-describing-coordinate-reference-systems
#   proj = self._crs.to_proj4(version=version)

# %%
an.pair_data()
an.plotting()
an.stats()
# Out:
# 1, in pair data
# After pairing:                       time     Column 2   Column 3   Column 4    Column 5
# 0     2021-08-27 20:00:00  7909.870605  18.450001  39.090000  226.834991  \
# 1     2021-08-27 21:00:00  7909.893066  24.584000  44.034000  236.285980
# 2     2021-08-27 22:00:00  7909.932617  24.600000  53.736000  249.800003
# 3     2021-08-27 23:00:00  7909.974121  24.598333  64.758331  261.173340
# 4     2021-08-28 00:00:00  7910.014648  24.700001  75.942001  270.917999
# ...                   ...          ...        ...        ...         ...
# 14458 2025-02-10 21:00:00  9172.896484  24.642307  62.713848  217.559235
# 14459 2025-02-10 22:00:00  9172.937500  24.613125  70.653748  230.714371
# 14460 2025-02-10 23:00:00  9172.972656  24.727501  78.526253  240.383759
# 14461 2025-02-11 14:00:00  9173.607422  24.975000  84.384995  113.330002
# 14462 2025-02-11 15:00:00  9173.644531  24.578571  75.362137  122.897850
#
#          Column 6    Column 7   Column 8    Column 9  Column 10  ...
# 0      120.699997  323.024994  88.500000   20.000000   0.000448  ...  \
# 1      123.778000  331.335999  89.000000   20.000000   0.000446  ...
# 2      127.288002  347.195984  89.000000   20.000000   0.000526  ...
# 3      127.898338   64.824997  89.000000   20.000000   0.000562  ...
# 4      125.195999   21.604000  89.000000   20.000000   0.000699  ...
# ...           ...         ...        ...         ...        ...  ...
# 14458  100.233849   47.733845  86.461540  101.492310   0.000430  ...
# 14459   91.607498   57.694374  86.062500  142.287506   0.000529  ...
# 14460   83.568748   65.378754  86.875000  115.850006   0.000830  ...
# 14461   98.294998  305.320007  88.994995   77.300003   0.002487  ...
# 14462  105.942139  314.903564  86.285713  113.171432   0.000936  ...
#
#        Column 112    Column 113  Column 114  Column 115  Column 116
# 0             NaN           NaN         NaN         NaN         NaN  \
# 1           2.240  1.058900e-06       2.260    3.130400       2.260
# 2           2.150  9.372100e-08       2.180    1.670800       2.180
# 3           2.060  4.314000e-07       2.120    7.038000       2.120
# 4           2.200  4.225400e-07       2.245    5.927700       2.245
# ...           ...           ...         ...         ...         ...
# 14458         NaN           NaN         NaN         NaN         NaN
# 14459         NaN           NaN         NaN         NaN         NaN
# 14460       1.550  4.806600e-06       1.815   39.151802       1.815
# 14461       1.115  1.075045e-05       1.620    0.197995       1.620
# 14462         NaN           NaN         NaN         NaN         NaN
#
#          Column 117          siteid  latitude  longitude  NO2
# 0               NaN  BoulderCO-NCAR   40.0375   -105.242  NaN
# 1      2.162400e-08  BoulderCO-NCAR   40.0375   -105.242  NaN
# 2      6.049300e-09  BoulderCO-NCAR   40.0375   -105.242  NaN
# 3      1.009100e-07  BoulderCO-NCAR   40.0375   -105.242  NaN
# 4      7.002550e-08  BoulderCO-NCAR   40.0375   -105.242  NaN
# ...             ...             ...       ...        ...  ...
# 14458           NaN  BoulderCO-NCAR   40.0375   -105.242  NaN
# 14459           NaN  BoulderCO-NCAR   40.0375   -105.242  NaN
# 14460  3.981000e-06  BoulderCO-NCAR   40.0375   -105.242  NaN
# 14461  1.236170e-05  BoulderCO-NCAR   40.0375   -105.242  NaN
# 14462           NaN  BoulderCO-NCAR   40.0375   -105.242  NaN
#
# [14463 rows x 121 columns]
# saving pair
# Warning: vmin_plot and vmax_plot not specified for PANDORA_NO2, so default used.
# Warning: vmin_plot and vmax_plot not specified for PANDORA_NO2, so default used.
# Warning: vdiff_plot not specified for PANDORA_NO2, so default used.
# Warning: vmin_plot and vmax_plot not specified for PANDORA_NO2, so default used.
# NOTE: Projection not defined for model 'camx'. Please add to surfplots.py. Setting to `ccrs.PlateCarree()`.
