# %% [markdown]
# # Using MELODIES-MONET for SIP evaluation
#
# First, import the relevant library

# %%
from melodies_monet import driver

# %% [markdown]
# ## Reading the YAML file

# %%
an = driver.analysis()
an.control = "control_airnow_camx.yaml"
an.read_control()

# %% [markdown]
# ## Opening obs and models

# %%
an.open_models()
an.open_obs()
# Out:
# camx
# /glade/work/plichtig/camx/processors/wrfcamx_v5.2/camx_input/CAMx73.cb7r1_cf3.20220720.35.camx.avrg.grd03.nc
# /glade/u/home/plichtig/melodies-monet/monetio/monetio/models/_camx_mm.py:78: UserWarning: Filename for meteorological input not provided. Adding only altitude.
#   warnings.warn("Filename for meteorological input not provided. Adding only altitude.")
# /glade/work/plichtig/conda-envs/melodies-monet-test/lib/python3.11/site-packages/pyproj/crs/crs.py:1293: UserWarning: You will likely lose important projection information when converting to a PROJ string from another format. See: https://proj.org/faq.html#what-is-the-best-format-for-describing-coordinate-reference-systems
#   proj = self._crs.to_proj4(version=version)

# %% [markdown]
# ## Pair data and (if desired) save analysis

# %%
an.pair_data()
an.save_analysis()
# Out:
# 1, in pair data
# After pairing:                        time  BARPR   BC    CO  NH3   NO           NO2  NO2Y  \
# 0      2022-07-20 00:00:00   -1.0 -1.0 -1.00 -1.0 -1.0 -1.000000e+00  -1.0
# 1      2022-07-20 00:00:00   -1.0 -1.0 -1.00 -1.0  0.4  6.984919e-09  -1.0
# 2      2022-07-20 00:00:00   -1.0 -1.0 -1.00 -1.0  0.1  6.984919e-09  -1.0
# 3      2022-07-20 00:00:00   -1.0 -1.0 -1.00 -1.0  0.3  6.984919e-09  -1.0
# 4      2022-07-20 00:00:00   -1.0 -1.0  0.12 -1.0  3.6  4.000000e+00  -1.0
# ...                    ...    ...  ...   ...  ...  ...           ...   ...
# 278770 2022-07-21 00:30:00   -1.0 -1.0 -1.00 -1.0 -1.0 -1.000000e+00  -1.0
# 278771 2022-07-21 00:30:00   -1.0 -1.0 -1.00 -1.0 -1.0 -1.000000e+00  -1.0
# 278772 2022-07-21 00:30:00   -1.0 -1.0 -1.00 -1.0 -1.0 -1.000000e+00  -1.0
# 278773 2022-07-21 00:30:00   -1.0 -1.0 -1.00 -1.0 -1.0 -1.000000e+00  -1.0
# 278774 2022-07-21 00:30:00   -1.0 -1.0 -1.00 -1.0 -1.0 -1.000000e+00  -1.0
#
#         NOX  NOY  ...  utcoffset   latitude   longitude  cmsa_name  \
# 0      -1.0 -1.0  ...         -4  53.304700  -60.364400       -1.0
# 1      -1.0 -1.0  ...         -4  46.240600  -63.130600       -1.0
# 2      -1.0 -1.0  ...         -4  46.478300  -63.986900       -1.0
# 3      -1.0 -1.0  ...         -4  46.386400  -62.582800       -1.0
# 4       7.3 -1.0  ...         -4  44.647175  -63.573689       -1.0
# ...     ...  ...  ...        ...        ...         ...        ...
# 278770 -1.0 -1.0  ...         -5  41.330470  -70.785840       -1.0
# 278771 -1.0 -1.0  ...         -5  34.912630  -80.874283       -1.0
# 278772 -1.0 -1.0  ...         -8  36.233333 -119.765083       -1.0
# 278773 -1.0 -1.0  ...         -6  36.922222  -94.838890       -1.0
# 278774 -1.0 -1.0  ...          8  47.928385  106.929470       -1.0
#
#             msa_code                             msa_name  state_name  \
# 0          -1.000000                                               CC
# 1          -1.000000                                               CC
# 2          -1.000000                                               CC
# 3          -1.000000                                               CC
# 4          -1.000000                                               CC
# ...              ...                                  ...         ...
# 278770     -1.000000
# 278771  16740.000002   Charlotte-Gastonia-Concord, NC-SC           SC
# 278772     -1.000000
# 278773  33059.999999                           Miami, OK
# 278774     -1.000000
#
#         epa_region  O3  NO2_new
# 0               CA NaN      NaN
# 1               CA NaN      NaN
# 2               CA NaN      NaN
# 3               CA NaN      NaN
# 4               CA NaN      NaN
# ...            ...  ..      ...
# 278770          R1 NaN      NaN
# 278771          R4 NaN      NaN
# 278772             NaN      NaN
# 278773          R6 NaN      NaN
# 278774        DSMG NaN      NaN
#
# [278775 rows x 37 columns]
# saving pair
# Writing: ./output/airnow/airnow_camx.nc4

# %% [markdown]
# ## Read analysis (if needed) and plot
#
# If the model has not been loaded, but you wish to plot spatial overlays, load

# %%
an.plotting()
# Out:
# Warning: vmin_plot and vmax_plot not specified for OZONE, so default used.
# Warning: vmin_plot and vmax_plot not specified for NO2, so default used.
# Warning: ty_scale not specified for OZONE, so default used.
# Reference std: 27.668546995598522
# Warning: ty_scale not specified for NO2, so default used.
# Reference std: 5.315197570030489
# Warning: vdiff_plot not specified for OZONE, so default used.
# Warning: vdiff_plot not specified for NO2, so default used.
# Warning: vmin_plot and vmax_plot not specified for OZONE, so default used.
# NOTE: Projection not defined for model 'camx'. Please add to surfplots.py. Setting to `ccrs.PlateCarree()`.
# Warning: vmin_plot and vmax_plot not specified for NO2, so default used.
# NOTE: Projection not defined for model 'camx'. Please add to surfplots.py. Setting to `ccrs.PlateCarree()`.

# %% [markdown]
# ## Calculate statistics

# %%
an.stats()
