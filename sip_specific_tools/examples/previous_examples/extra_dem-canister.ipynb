# %%
from melodies_monet import driver

an = driver.analysis()
an.control = 'control_canister_camx.yaml'
an.read_control()
an.open_obs()
an.open_models()
an.pair_data()
an.plotting()
# Out:
# camx
# /glade/campaign/acom/acom-da/Denver2024-SIP/Denver_O3_2023/camx/outputs/runS20_2016/camxv72_cb6r5.20160[6-9]*.runS20.avrg.grd03.nc
# /glade/work/plichtig/conda-envs/melodies-monet-test/lib/python3.11/site-packages/pyproj/crs/crs.py:1293: UserWarning: You will likely lose important projection information when converting to a PROJ string from another format. See: https://proj.org/faq.html#what-is-the-best-format-for-describing-coordinate-reference-systems
#   proj = self._crs.to_proj4(version=version)
# 1, in pair data
# After pairing:                    time  1,2,4-Trimethylbenzene          time_local  \
# 0  2016-01-01 13:00:00                  0.4190 2016-01-01 06:00:00
# 1  2016-01-07 13:00:00                  2.0300 2016-01-07 06:00:00
# 2  2016-01-19 13:00:00                  1.3300 2016-01-19 06:00:00
# 3  2016-01-25 13:00:00                  0.5030 2016-01-25 06:00:00
# 4  2016-02-27 13:00:00                  2.0800 2016-02-27 06:00:00
# ...
